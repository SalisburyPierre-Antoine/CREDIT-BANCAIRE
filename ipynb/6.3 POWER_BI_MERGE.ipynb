# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt  
import seaborn as sns

# %%
# On importe le csv client POWER BI
dfclient = pd.read_csv('/Users/p-asalisbury/Dropbox/Mon Mac (MacBook Air de P-A)/Desktop/Chef_doeuvre/CSV_MySQL/POWER_BI_CLIENT.csv')
# On indique vouloir garder toutes les colonnes
pd.set_option('display.max_columns',None)
dfclient.head()
# Out:
#    id_client  cible    age genre                   niveau_etude  \
# 0     100002      1  20-30     M  Secondary / secondary special
# 1     100003      0  40-50     F               Higher education
# 2     100004      0  50-60     M  Secondary / secondary special
# 3     100006      0  50-60     F  Secondary / secondary special
# 4     100007      0  50-60     M  Secondary / secondary special
#
#      statut_matrimonial  nombre_enfants   accompagnant  total_revenus  \
# 0  Single / not married               0  Unaccompanied              6
# 1               Married               0         Family              8
# 2  Single / not married               0  Unaccompanied              0
# 3        Civil marriage               0  Unaccompanied              3
# 4  Single / not married               0  Unaccompanied              2
#
#      type_revenu categorie_pro type_entreprise anciennete  telephone_pro  \
# 0        Working      Laborers        Affaires        0-1              1
# ...

# %%
# On importe le csv credit
dfcredit = pd.read_csv('/Users/p-asalisbury/Dropbox/Mon Mac (MacBook Air de P-A)/Desktop/Chef_doeuvre/CSV_MySQL/POWER_BI_CREDIT.csv')
# On indique vouloir garder toutes les colonnes
pd.set_option('display.max_columns',None)
dfcredit.head()
# Out:
#    id_credit  id_client     type_credit  montant_demande_credit  \
# 0    2030495     271877  Consumer loans                   17145
# 1    2802425     108129      Cash loans                  607500
# 2    2523466     122040      Cash loans                  112500
# 3    2819243     176158      Cash loans                  450000
# 4    1784265     202054      Cash loans                  337500
#
#    montant_credit_accorde statut_contrat  nombre_mois_decision  \
# 0                   17145       Approved                     2
# 1                  607500       Approved                     5
# 2                  112500       Approved                    10
# 3                  450000       Approved                    17
# 4                  337500        Refused                    26
#
#        moyen_de_paiement raison_rejet                type_bien
# 0  Cash through the bank          XAP  Téléphonie, Audio/Vidéo
# 1                    XNA          XAP                      XNA
# ...

# %%
dfmerge = pd.merge(dfclient, dfcredit, on="id_client")
dfmerge.head()
# Out:
#    id_client  cible    age genre                   niveau_etude  \
# 0     100002      1  20-30     M  Secondary / secondary special
# 1     100003      0  40-50     F               Higher education
# 2     100003      0  40-50     F               Higher education
# 3     100003      0  40-50     F               Higher education
# 4     100004      0  50-60     M  Secondary / secondary special
#
#      statut_matrimonial  nombre_enfants   accompagnant  total_revenus  \
# 0  Single / not married               0  Unaccompanied              6
# 1               Married               0         Family              8
# 2               Married               0         Family              8
# 3               Married               0         Family              8
# 4  Single / not married               0  Unaccompanied              0
#
#      type_revenu categorie_pro type_entreprise anciennete  telephone_pro  \
# 0        Working      Laborers        Affaires        0-1              1
# ...

# %%
# On importe le csv type_credit
dftype_credit = pd.read_csv('/Users/p-asalisbury/Dropbox/Mon Mac (MacBook Air de P-A)/Desktop/Chef_doeuvre/CSV_MySQL/POWER_BI_TYPE_CREDIT.csv')

dftype_credit.head()
# Out:
#    id_type      type_credit
# 0        0       Cash loans
# 1        1   Consumer loans
# 2        2  Revolving loans
# 3        3              XNA

# %%
dfmerge1 = pd.merge(dfmerge,dftype_credit,  on="type_credit")
dfmerge1.head()
# Out:
#    id_client  cible    age genre                   niveau_etude  \
# 0     100002      1  20-30     M  Secondary / secondary special
# 1     100003      0  40-50     F               Higher education
# 2     100003      0  40-50     F               Higher education
# 3     100004      0  50-60     M  Secondary / secondary special
# 4     100006      0  50-60     F  Secondary / secondary special
#
#      statut_matrimonial  nombre_enfants   accompagnant  total_revenus  \
# 0  Single / not married               0  Unaccompanied              6
# 1               Married               0         Family              8
# 2               Married               0         Family              8
# 3  Single / not married               0  Unaccompanied              0
# 4        Civil marriage               0  Unaccompanied              3
#
#      type_revenu categorie_pro type_entreprise anciennete  telephone_pro  \
# 0        Working      Laborers        Affaires        0-1              1
# ...

# %%
# On importe le csv bien
dfbien = pd.read_csv('/Users/p-asalisbury/Dropbox/Mon Mac (MacBook Air de P-A)/Desktop/Chef_doeuvre/CSV_MySQL/POWER_BI_TYPE_BIEN.csv')

dfbien.head()
# Out:
#    id_bien                type_bien
# 0        0                      XNA
# 1        1  Vêtements et accessoirs
# 2        2                   Maison
# 3        3  Téléphonie, Audio/Vidéo
# 4        4                   Bijoux

# %%
dfmerge2 = pd.merge(dfmerge1,dfbien,  on="type_bien")
dfmerge2.head()
# Out:
#    id_client  cible    age genre                   niveau_etude  \
# 0     100002      1  20-30     M  Secondary / secondary special
# 1     100097      0  40-50     M  Secondary / secondary special
# 2     100297      0  20-30     M  Secondary / secondary special
# 3     100297      0  20-30     M  Secondary / secondary special
# 4     100301      1  20-30     M  Secondary / secondary special
#
#      statut_matrimonial  nombre_enfants   accompagnant  total_revenus  \
# 0  Single / not married               0  Unaccompanied              6
# 1               Married               0  Unaccompanied              4
# 2               Married               0         Family              3
# 3               Married               0         Family              3
# 4               Married               1  Unaccompanied              1
#
#   type_revenu categorie_pro    type_entreprise anciennete  telephone_pro  \
# 0     Working      Laborers           Affaires        0-1              1
# ...

# %%
import csv
dfmerge2.to_csv('POWER_BI_MERGE_MySQL.csv', index=False, quoting=csv.QUOTE_NONNUMERIC)
